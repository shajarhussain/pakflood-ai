# %% [markdown]
# # PakFlood AI — Data Exploration
#
# This notebook explores the seed data and external data sources for the flood risk model.
#
# **Phase:** 3 — Data Adapters & Source Registry

# %%
import json
import pandas as pd

# Load seed risk data
with open('../../data/seed/mock_risk.json') as f:
    risk_data = json.load(f)

df = pd.DataFrame(risk_data)
print(df.head())
print('\nRisk level distribution:')
print(df['risk_level'].value_counts())

# %% [markdown]
# ## Next Steps
# - Load CHIRPS historical rainfall for Pakistan districts
# - Compute antecedent wetness features (3d/7d/30d aggregations)
# - Explore GloFAS discharge correlation with flood events
